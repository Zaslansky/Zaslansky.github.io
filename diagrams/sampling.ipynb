# %%
import matplotlib.pyplot as plt
import nltk
import pandas as pd
import numpy as np
from numpy import pi
import math
figdpi=1000
import seaborn as sns

def sinsig(time, amplitude, frequency, phase):
    return amplitude * np.sin(frequency * time + phase)

# %%
x=sinsig(2,2,200,0)
x
# Out:
# -1.701838719278353

# %%
x= np.linspace(0, 2*np.pi, 50)
df = pd.DataFrame(x)
df[0]
df["sin"]=np.sin(x)
df["zero"]=0
df["diff"]=df[0].iloc[0]-df[0].iloc[1]
df
# Out:
#            0           sin  zero      diff
# 0   0.000000  0.000000e+00     0 -0.128228
# 1   0.128228  1.278772e-01     0 -0.128228
# 2   0.256457  2.536546e-01     0 -0.128228
# 3   0.384685  3.752670e-01     0 -0.128228
# 4   0.512913  4.907176e-01     0 -0.128228
# 5   0.641141  5.981105e-01     0 -0.128228
# 6   0.769370  6.956826e-01     0 -0.128228
# 7   0.897598  7.818315e-01     0 -0.128228
# 8   1.025826  8.551428e-01     0 -0.128228
# 9   1.154054  9.144126e-01     0 -0.128228
# 10  1.282283  9.586679e-01     0 -0.128228
# 11  1.410511  9.871818e-01     0 -0.128228
# 12  1.538739  9.994862e-01     0 -0.128228
# 13  1.666968  9.953791e-01     0 -0.128228
# 14  1.795196  9.749279e-01     0 -0.128228
# 15  1.923424  9.384684e-01     0 -0.128228
# 16  2.051652  8.865993e-01     0 -0.128228
# 17  2.179881  8.201723e-01     0 -0.128228
# 18  2.308109  7.402780e-01     0 -0.128228
# 19  2.436337  6.482284e-01     0 -0.128228
# 20  2.564565  5.455349e-01     0 -0.128228
# ...

# %%
plt.plot(df["zero"],color="lightgray")
plt
#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')
plt.plot(df["sin"], marker=".",color="black")
plt.box(False)
plt.savefig('sampling_sampled.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.plot(df["zero"],color="lightgray")
plt
#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')
plt.plot(df["sin"], marker=".",color="black")
plt.box(False)
plt.savefig('sampling_sampled.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.plot(df["zero"],color="lightgray")
#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')
for xc in range(0,len(df)):
    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sin"], marker=".",color="black")
plt.box(False)

plt.savefig('sampling_withlines.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.plot(df["zero"],color="lightgray")
#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')
for xc in range(0,len(df)):
    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
#plt.plot(df["sin"], marker=".",color="black")
plt.box(False)

plt.savefig('sampling_justlines.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.plot(df["zero"],color="lightgray")
#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')
#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sin"], marker="",color="black")
plt.box(False)

plt.savefig('sampling_justwave.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
x= np.linspace(0, 2*np.pi, 8)
df = pd.DataFrame(x)
df[0]
df["sin"]=np.sin(x)
df["zero"]=0
df["diff"]=df[0].iloc[0]-df[0].iloc[1]
df
# Out:
#           0           sin  zero      diff
# 0  0.000000  0.000000e+00     0 -0.897598
# 1  0.897598  7.818315e-01     0 -0.897598
# 2  1.795196  9.749279e-01     0 -0.897598
# 3  2.692794  4.338837e-01     0 -0.897598
# 4  3.590392 -4.338837e-01     0 -0.897598
# 5  4.487990 -9.749279e-01     0 -0.897598
# 6  5.385587 -7.818315e-01     0 -0.897598
# 7  6.283185 -2.449294e-16     0 -0.897598

# %%
plt.plot(df["zero"],color="lightgray")
#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')
#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sin"], marker=".",color="black")
plt.box(False)

plt.savefig('sampling_lowrate.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.plot(df["zero"],color="lightgray")
#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')
for xc in range(0,len(df)):
    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='lightgray')
plt.plot(df["sin"], marker=".",color="black")
plt.box(False)

plt.savefig('sampling_lowratejustlines.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
x= np.linspace(0, 2*np.pi, 1000)
df = pd.DataFrame(x)
df[0]
df["sin"]=np.sin(x)
df["zero"]=0
df["diff"]=df[0].iloc[0]-df[0].iloc[1]
df

plt.plot(df["zero"],color="lightgray")
#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')
#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sin"], marker="",color="black")
plt.box(False)

plt.savefig('sampling_perfectwave.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
x= np.linspace(0, 2*np.pi, 6)
df = pd.DataFrame(x)
df[0]
df["sin"]=np.sin(x)
df["zero"]=0
df["diff"]=df[0].iloc[0]-df[0].iloc[1]
df

plt.plot(df["zero"],color="lightgray")
#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')
#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sin"], marker=".",color="black")
plt.box(False)

plt.savefig('sampling_verylow.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
x= np.linspace(0, 2*np.pi, 4)
df = pd.DataFrame(x)
df[0]
df["sin"]=np.sin(x)
df["zero"]=0
df["diff"]=df[0].iloc[0]-df[0].iloc[1]
df

plt.plot(df["zero"],color="lightgray")
#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')
#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sin"], marker=".",color="black")
plt.box(False)

plt.savefig('sampling_verylow2.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
cols = {}
cols.update({"x1":np.sin(np.linspace(0, 20, 200)*3)*4})

df = pd.DataFrame(cols)
df["sin"]=df["x1"]
df["zero"]=0
tc = 4
ylim =8
df["topclip"]=tc
df["bottomclip"]=0-tc
df["sincut"]=df['sin']
df['sincut'] = df['sincut'].apply(lambda x: tc if x > tc else x)
df['sincut'] = df['sincut'].apply(lambda x: -tc if x < -tc else x)

df.loc[df['sin'] <= tc, 'equal_or_lower_than_4?'] = 'True' 
plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')
ax.set_xlim(0, 180)

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sin"], marker=".",color="black")
plt.box(False)
ax.set_xlim(0, 180)

plt.savefig('sampling_sampled_hifreq.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
cols = {}
cols.update({"x1":np.sin(np.linspace(0,90, 200)*3)*4})

df = pd.DataFrame(cols)
df["sin"]=df["x1"]
df["zero"]=0
tc = 4
ylim =8
df["topclip"]=tc
df["bottomclip"]=0-tc
df["sincut"]=df['sin']
df['sincut'] = df['sincut'].apply(lambda x: tc if x > tc else x)
df['sincut'] = df['sincut'].apply(lambda x: -tc if x < -tc else x)

df.loc[df['sin'] <= tc, 'equal_or_lower_than_4?'] = 'True' 
plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')
ax.set_xlim(0, 180)

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sin"], marker=".",color="black")
plt.box(False)
ax.set_xlim(0, 180)

plt.savefig('sampling_sampled_ultrahifreq.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
sr = 10000                       # samp rate in Hz
f = 200                          # frequency of signal 
tmax = 2                        # duration of signal, in seconds
dt = 1/sr                       # time step, reciprocal of the sr
t = np.arange(0,tmax,dt)        # time axis

# make a sin wave - amp is 1
sw1 = np.sin( 2*pi*100*t )*2
sw2 = np.sin( 2*pi*200*t )*6
sw3 = np.sin( 2*pi*300*t )*2
sw4 = np.sin( 2*pi*400*t )*4


cols = {}
cols.update({"x1":sw1})
cols.update({"x2":sw2})
cols.update({"x3":sw3})
cols.update({"x4":sw4})

df = pd.DataFrame(cols)
df["sin"]=df["x1"]+df["x2"]+df["x3"]+df["x4"]
df["zero"]=0
tc = 4
ylim =12
df["topclip"]=tc
df["bottomclip"]=0-tc
df["sincut"]=df['sin']
df['sincut'] = df['sincut'].apply(lambda x: tc if x > tc else x)
df['sincut'] = df['sincut'].apply(lambda x: -tc if x < -tc else x)
plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sin"], marker=".",color="black")
ax.set_ylim(-ylim, ylim)
plt.box(False)
ax.set_xlim(0, 180)
plt.savefig('sampling_clip_orig.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.plot(df["zero"],color="lightgray")
plt.plot(df["topclip"],'--', color="red")
plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sin"], marker=".",color="black")
ax.set_ylim(-ylim, ylim)
plt.box(False)
ax.set_xlim(0, 180)
plt.savefig('sampling_clip_cutoff.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])

ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')
ax.set_ylim(-ylim, ylim)

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sincut"], marker=".",color="black")
plt.box(False)
ax.set_xlim(0, 180)
N=500
plt.savefig('sampling_clip_clipped.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.subplot(121)
plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sin"], marker="",color="black")
ax.set_ylim(-ylim, ylim)
plt.box(False)
ax.set_xlim(0, 180)
plt.subplot(122)

plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])

ax = plt.gca()
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')

y = np.fft.rfft(df["sin"])
print(y)
plt.plot(abs(y)-5, marker="",color="black")
plt.xlim(0, 2000)
plt.box(False)

plt.savefig('sampling_clip_orig_fft.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)
# Out:
# [ 3.40422438e-11+0.00000000e+00j -3.36283452e-12+2.07778708e-11j
#  -1.68336486e-11+4.21320665e-12j ...  2.91868657e-11+5.04569045e-12j
#   1.80509042e-11+5.96852378e-15j  2.28440903e-11+0.00000000e+00j]

# %%
plt.subplot(121)
plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sincut"], marker="",color="black")
ax.set_ylim(-ylim, ylim)
plt.box(False)
ax.set_xlim(0, 180)
plt.subplot(122)

plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])

ax = plt.gca()
ax.get_yaxis().set_visible(False)
plt.axvline(x = 0, color = 'lightgray')

y = np.fft.rfft(df["sincut"])
plt.plot(abs(y), marker="",color="black")
plt.xlim(0, 2000)
plt.box(False)

plt.savefig('sampling_clip_clipped_fft.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
sr = 10000                       # samp rate in Hz
f = 200                          # frequency of signal 
tmax = 2                        # duration of signal, in seconds
dt = 1/sr                       # time step, reciprocal of the sr
t = np.arange(0,tmax,dt)        # time axis

# make a sin wave - amp is 1
sw1 = np.sin( 2*pi*100*t )*2
sw2 = np.sin( 2*pi*200*t )*6
sw3 = np.sin( 2*pi*300*t )*2
sw4 = np.sin( 2*pi*400*t )*4


cols = {}
cols.update({"x1":sw1})
cols.update({"x2":sw2})
cols.update({"x3":sw3})
cols.update({"x4":sw4})

df = pd.DataFrame(cols)
df["sin"]=df["x1"]+df["x2"]+df["x3"]+df["x4"]
df["zero"]=0
tc = 4
ylim =12
df["topclip"]=tc
df["bottomclip"]=0-tc
df["sincut"]=df['sin']
df['sincut'] = df['sincut'].apply(lambda x: tc if x > tc else x)
df['sincut'] = df['sincut'].apply(lambda x: -tc if x < -tc else x)
plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
plt.axvline(x = 0, color = 'lightgray')

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sin"], marker="",color="black")
ax.set_ylim(-ylim, ylim)
plt.box(False)
ax.set_xlim(0, 180)
plt.savefig('fft_combined.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
plt.axvline(x = 0, color = 'lightgray')

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["x1"], marker="",color="red",alpha=0.5)
plt.plot(df["x2"], marker="",color="blue",alpha=0.5)
plt.plot(df["x3"], marker="",color="green",alpha=0.5)
plt.plot(df["x4"], marker="",color="purple",alpha=0.5)

plt.plot(df["sin"], marker="",color="black")
ax.set_ylim(-ylim, ylim)
plt.box(False)
ax.set_xlim(0, 180)
plt.savefig('fft_withwaves.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
plt.axvline(x = 0, color = 'lightgray')

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["x1"], marker="",color="red",alpha=1)
plt.plot(df["x2"], marker="",color="blue",alpha=1)
plt.plot(df["x3"], marker="",color="green",alpha=1)
plt.plot(df["x4"], marker="",color="purple",alpha=1)
ax.set_ylim(-ylim, ylim)
plt.box(False)
ax.set_xlim(0, 180)
plt.savefig('fft_withwaves.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
plt.axvline(x = 0, color = 'lightgray')
ax.get_yaxis().set_visible(False)

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(abs(np.fft.rfft(df["x1"])), marker="",color="red",alpha=1)
plt.plot(abs(np.fft.rfft(df["x2"])), marker="",color="blue",alpha=1)
plt.plot(abs(np.fft.rfft(df["x3"])), marker="",color="green",alpha=1)
plt.plot(abs(np.fft.rfft(df["x4"])), marker="",color="purple",alpha=1)
plt.box(False)
ax.set_xlim(0, 1000)
plt.savefig('fft_separated_fft.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
plt.axvline(x = 0, color = 'lightgray')
ax.get_yaxis().set_visible(False)

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(abs(np.fft.rfft(df["sin"])), marker="",color="black",alpha=1)
plt.box(False)
ax.set_xlim(0, 1000)
plt.savefig('fft_combined_fft.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.subplot(121)
plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
plt.axvline(x = 0, color = 'lightgray')

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["x1"], marker="",color="red",alpha=1)
plt.plot(df["x2"], marker="",color="blue",alpha=1)
plt.plot(df["x3"], marker="",color="green",alpha=1)
plt.plot(df["x4"], marker="",color="purple",alpha=1)
ax.set_ylim(-ylim, ylim)
plt.box(False)
ax.set_xlim(0, 180)
plt.subplot(122)

plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
plt.axvline(x = 0, color = 'lightgray')
ax.get_yaxis().set_visible(False)

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(abs(np.fft.rfft(df["x1"])), marker="",color="red",alpha=0.75)
plt.plot(abs(np.fft.rfft(df["x2"])), marker="",color="blue",alpha=0.75)
plt.plot(abs(np.fft.rfft(df["x3"])), marker="",color="green",alpha=0.75)
plt.plot(abs(np.fft.rfft(df["x4"])), marker="",color="purple",alpha=0.75)
plt.box(False)
ax.set_xlim(0, 1000)
plt.savefig('fft_separated_wavefft.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
plt.subplot(121)
plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
plt.axvline(x = 0, color = 'lightgray')

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(df["sin"], marker="",color="black",alpha=1)
ax.set_ylim(-ylim, ylim)
plt.box(False)
ax.set_xlim(0, 180)
plt.subplot(122)

plt.plot(df["zero"],color="lightgray")
#plt.plot(df["topclip"],'--', color="red")
#plt.plot(df["bottomclip"],'--',color="red")

#plt.xticks([])
#plt.yticks([])
ax = plt.gca()
plt.axvline(x = 0, color = 'lightgray')
ax.get_yaxis().set_visible(False)

#for xc in range(0,len(df)):
#    plt.plot([xc,xc],[0,df.at[xc, "sin"]],color='gray')
plt.plot(abs(np.fft.rfft(df["sin"])), marker="",color="black",alpha=1)
plt.box(False)
ax.set_xlim(0, 1000)
plt.savefig('fft_combined_wavefft.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
df.reset_index(inplace=True)
df
# Out:
#        index        x1        x2        x3        x4       sin  zero  topclip  \
# 0          0  0.000000  0.000000  0.000000  0.000000  0.000000     0        4
# 1          1  0.125581  0.751999  0.374763  0.994760  2.247103     0        4
# 2          2  0.250666  1.492139  0.736249  1.927015  4.406070     0        4
# 3          3  0.374763  2.208747  1.071654  2.738188  6.393352     0        4
# 4          4  0.497380  2.890522  1.369094  3.377312  8.134308     0        4
# ...      ...       ...       ...       ...       ...       ...   ...      ...
# 19995  19995 -0.618034 -3.526712 -1.618034 -3.804226 -9.567006     0        4
# 19996  19996 -0.497380 -2.890522 -1.369094 -3.377312 -8.134308     0        4
# 19997  19997 -0.374763 -2.208747 -1.071654 -2.738188 -6.393352     0        4
# 19998  19998 -0.250666 -1.492139 -0.736249 -1.927015 -4.406070     0        4
# 19999  19999 -0.125581 -0.751999 -0.374763 -0.994760 -2.247103     0        4
#
#        bottomclip    sincut
# ...

# %%
sr = 10000                       # samp rate in Hz
f = 200                          # frequency of signal 
tmax = 2                        # duration of signal, in seconds
dt = 1/sr                       # time step, reciprocal of the sr
t = np.arange(0,tmax,dt)        # time axis

# make a sin wave - amp is 1
sw1 = np.sin( 2*pi*100*t+(2*pi))*1
sw2 = np.sin( 2*pi*100*t+(0.5*pi))*1
sw3 = np.sin( 2*pi*100*t+(pi))*1
sw4 = np.sin( 2*pi*100*t+(1.5*pi))*1



cols = {}
cols.update({"phase_0":sw1})
cols.update({"phase_90":sw2})
cols.update({"phase_180":sw3})
cols.update({"phase_270":sw4})

df = pd.DataFrame.from_dict(cols)
df.reset_index(inplace=True)
df= df.rename(columns={'index':'time'})
df
# Out:
#         time       phase_0  phase_90     phase_180  phase_270
# 0          0 -2.449294e-16  1.000000  1.224647e-16  -1.000000
# 1          1  6.279052e-02  0.998027 -6.279052e-02  -0.998027
# 2          2  1.253332e-01  0.992115 -1.253332e-01  -0.992115
# 3          3  1.873813e-01  0.982287 -1.873813e-01  -0.982287
# 4          4  2.486899e-01  0.968583 -2.486899e-01  -0.968583
# ...      ...           ...       ...           ...        ...
# 19995  19995 -3.090170e-01  0.951057  3.090170e-01  -0.951057
# 19996  19996 -2.486899e-01  0.968583  2.486899e-01  -0.968583
# 19997  19997 -1.873813e-01  0.982287  1.873813e-01  -0.982287
# 19998  19998 -1.253332e-01  0.992115  1.253332e-01  -0.992115
# 19999  19999 -6.279052e-02  0.998027  6.279052e-02  -0.998027
#
# [20000 rows x 5 columns]

# %%
dt = pd.melt(df,
              id_vars='time',
              value_vars=['phase_0','phase_90','phase_180','phase_270'],
              var_name='phase',
              value_name='wave')
dt
#dt.set_index('time',inplace=True)
dt
# Out:
#         time      phase          wave
# 0          0    phase_0 -2.449294e-16
# 1          1    phase_0  6.279052e-02
# 2          2    phase_0  1.253332e-01
# 3          3    phase_0  1.873813e-01
# 4          4    phase_0  2.486899e-01
# ...      ...        ...           ...
# 79995  19995  phase_270 -9.510565e-01
# 79996  19996  phase_270 -9.685832e-01
# 79997  19997  phase_270 -9.822873e-01
# 79998  19998  phase_270 -9.921147e-01
# 79999  19999  phase_270 -9.980267e-01
#
# [80000 rows x 3 columns]

# %%
ax = plt.gca()
plt.style.use('tableau-colorblind10')
ax.set_ylim(-ylim, ylim)
plt.axhline(y=0, color='lightgray', linestyle='--')

dt.groupby('phase')['wave'].plot(legend=True)
plt.legend(bbox_to_anchor=(1,0.5), loc=6)
ax.axvline(x = 0, color = 'lightgray')
ax.set_xlabel('Time (arbitrary)')
ax.set_ylabel('Amplitude (arbitrary)')

ax.set_xlim(0, 200)
plt.box(False)
plt.savefig('phase_phases.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
ax = sns.lineplot(data=dt,x='time',y='wave',hue='phase')
plt.axhline(y=0, color='lightgray', linestyle='--')

plt.legend(bbox_to_anchor=(1,0.5), loc=6)
ax.axvline(x = 0, color = 'lightgray')
ax.set_xlabel('Time (arbitrary)')
ax.set_ylabel('Amplitude (arbitrary)')

ax.set_xlim(0, 200)
plt.box(False)
plt.savefig('phase_phases.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)

# %%
ax = sns.FacetGrid(dt, col="phase", col_wrap=6)

ax.map(sns.lineplot(y='wave'))
plt.axhline(y=0, color='lightgray', linestyle='--')

plt.legend(bbox_to_anchor=(1,0.5), loc=6)
ax.set_xlabel('Time (arbitrary)')
ax.set_ylabel('Amplitude (arbitrary)')

ax.set_xlim(0, 200)
plt.box(False)
plt.savefig('phase_phases_separate.png', dpi=figdpi,bbox_inches='tight', pad_inches=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 3
#       1 ax = sns.FacetGrid(dt, col="phase", col_wrap=6)
# ----> 3 ax.map(sns.lineplot(y='wave'))
#       4 plt.axhline(y=0, color='lightgray', linestyle='--')
#       6 plt.legend(bbox_to_anchor=(1,0.5), loc=6)
#
# File ~/.local/lib/python3.12/site-packages/seaborn/relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# ...
